# %%
# !gdown 19EWhcGURNRhE4hFvMDMJZKB6oc3EA5eY
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=19EWhcGURNRhE4hFvMDMJZKB6oc3EA5eY
# To: /content/CogNet-v2.0.tsv
# 100% 382M/382M [00:04<00:00, 94.6MB/s]

# %%
import pandas as pd

# %%
df = pd.read_csv('./CogNet-v2.0.tsv', sep='\t', error_bad_lines=False)
# Out:
# <ipython-input-3-cfe69dd3de9e>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv('./CogNet-v2.0.tsv', sep='\t', error_bad_lines=False)
# Skipping line 299077: expected 7 fields, saw 9
# Skipping line 299120: expected 7 fields, saw 9
# Skipping line 299129: expected 7 fields, saw 9
#
# Skipping line 506809: expected 7 fields, saw 9
#
# Skipping line 831507: expected 7 fields, saw 9
#
# Skipping line 1239093: expected 7 fields, saw 9
#
# Skipping line 2360370: expected 7 fields, saw 9
# Skipping line 2360383: expected 7 fields, saw 9
#
# Skipping line 2686003: expected 7 fields, saw 9
#
# Skipping line 2763282: expected 7 fields, saw 9
#
# Skipping line 5254685: expected 7 fields, saw 9
# Skipping line 5289724: expected 7 fields, saw 9
#
# Skipping line 5390339: expected 7 fields, saw 52

# %%
df
# Out:
#         concept id lang 1        word 1 lang 2         word 2 translit 1  \
# 0        n00001740    yue             體    hak              體        NaN
# 1        n00001740    eus      entitate    por       entidade        NaN
# 2        n00001740    eus      entitate    por           ente        NaN
# 3        n00001740    ita        entità    ell       οντότητα        NaN
# 4        n00001740    por      entidade    arg        entidat        NaN
# ...            ...    ...           ...    ...            ...        ...
# 5738731  r00516492    spa  injustamente    ita  ingiustamente        NaN
# 5738732  r00516492    slk     bezprávne    hrv      bespravno        NaN
# 5738733  r00516492    slk     bezprávne    pol     bezprawnie        NaN
# 5738734  r00516492    fra  illégalement    ita   illegalmente        NaN
# 5738735  r00516492    fra   injustement    ita  ingiustamente        NaN
#
#         translit 2
# 0              NaN
# 1              NaN
# 2              NaN
# ...

# %%
# Example
df[df['concept id'] == 'n05820620']
# Out:
#      concept id lang 1       word 1 lang 2     word 2 translit 1 translit 2
# 5876  n05820620    spa      ejemplo    fra    exemple        NaN        NaN
# 5877  n05820620    msa        misal    crh      misal        NaN        NaN
# 5878  n05820620    eng      example    dan   eksempel        NaN        NaN
# 5879  n05820620    nob     eksempel    fra    exemple        NaN        NaN
# 5880  n05820620    eng      example    ron    exemplu        NaN        NaN
# ...         ...    ...          ...    ...        ...        ...        ...
# 6049  n05820620    hrv  ilustracija    ces  ilustrace        NaN        NaN
# 6050  n05820620    ita      esempio    por    exemplo        NaN        NaN
# 6051  n05820620    fra      exemple    ast    exemplu        NaN        NaN
# 6052  n05820620    cat      exemple    por    exemplo        NaN        NaN
# 6053  n05820620    hin        नमूना    mya      နမူနာ     namuna    na.muna
#
# [178 rows x 7 columns]

# %%
# Looking at the words that are exactly same
s_words = df[(df['word 1'] == df['word 2'])]
s_words
# Out:
#         concept id lang 1            word 1 lang 2            word 2  \
# 0        n00001740    yue                 體    hak                 體
# 13       n00001740    glg          entidade    por          entidade
# 37       n00001740    ind            tablet    msa            tablet
# 66       n00001740    slk            entita    ces            entita
# 85       n00001740    ind           entitas    lat           entitas
# ...            ...    ...               ...    ...               ...
# 5738614  r00513248    eng             dolce    fin             dolce
# 5738621  r00513248    spa             dolce    ces             dolce
# 5738622  r00513248    spa             dolce    jpn             dolce
# 5738623  r00513248    spa             dolce    fin             dolce
# 5738661  r00514080    spa  irreparablemente    glg  irreparablemente
#
#         translit 1 translit 2
# 0              NaN        NaN
# 13             NaN        NaN
# 37             NaN        NaN
# ...
